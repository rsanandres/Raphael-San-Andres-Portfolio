# %%
#This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '1cc5375d-420b-4443-80a0-7944e4e21617',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2022-09-11T22:16:52.894Z', 'error_code': 0, 'error_message': None, 'elapsed': 70, 'credit_count': 1, 'notice': "You have used 100% of your plan's daily credit limit.", 'total_count': 9577}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 9727, 'date_added': '2013-04-28T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio'], 'max_supply': 21000000, 'circulating_supply': 19148118, 'total_supply': 19148118, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2022-09-11T22:14:00.000Z', 'quote': {'USD': {'price': 21617.48544746162, 'volume_24h': 34929529573.446014, 'volume_change_24h': -6.5165, 'percent_change_1h': -0.33788591, 'percent_change_24h': -0.34568721, 'percent_change_7d': 8.8997558, 'percent_change_30d': -10.31550482, 'percent_change_60d': 8.71869086, 'percent_change_90d': -5.85807344, 'market_cap': 413934162211.2779, 'market_cap_dominance': 39.2844, 'fully_diluted_market_cap': 453967194396.69, 'tvl': None, 'last_updated': '2022-09-11T22:14:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 6083, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['mineable', 'pow', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'injective-ecosystem'], 'max_supply': None, 'circulating_supply': 122331659.3115, 'total_supply': 122331659.3115, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2022-09-11T22:14:00.000Z', 'quote': {'USD': {'price': 1747.132127405775, 'volume_24h': 12752142746.63947, 'volume_change_24h': -0.4339, 'percent_change_1h': -0.86203198, 'percent_change_24h': -0.82705839, 'percent_change_7d': 11.41527961, 'percent_change_30d': -9.05820459, 'percent_change_60d': 60.68320748, 'percent_change_90d': 42.45040327, 'market_cap': 213729572181.9795, 'market_cap_dominance': 20.2854, 'fully_diluted_market_cap': 213729572181.98, 'tvl': None, 'last_updated': '2022-09-11T22:14:00.000Z'}}}, {'id': 825, 'name': 'Tether', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 39548, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['payments', 'stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin'], 'max_supply': None, 'circulating_supply': 67652203603.29136, 'total_supply': 69156782826.49281, 'platform': {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'token_address': '0xdac17f95 ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
#pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', lambda x: '%5f' % x)

# %%
df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
#       id         name symbol                  slug  num_market_pairs  \
# 0      1      Bitcoin    BTC               bitcoin              9727
# 1   1027     Ethereum    ETH              ethereum              6083
# 2    825       Tether   USDT                tether             39548
# 3   3408     USD Coin   USDC              usd-coin              6158
# 4   1839          BNB    BNB                   bnb              1099
# 5   4687  Binance USD   BUSD           binance-usd              5061
# 6     52          XRP    XRP                   xrp               813
# 7   2010      Cardano    ADA               cardano               568
# 8   5426       Solana    SOL                solana               380
# 9   6636     Polkadot    DOT          polkadot-new               408
# 10    74     Dogecoin   DOGE              dogecoin               560
# 11  3890      Polygon  MATIC               polygon               483
# 12  5994    Shiba Inu   SHIB             shiba-inu               413
# 13  4943          Dai    DAI  multi-collateral-dai              1331
# 14  5805    Avalanche   AVAX             avalanche               311
#
#                   date_added  \
# 0   2013-04-28T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2018-10-08T00:00:00.000Z
# 4   2017-07-25T00:00:00.000Z
# 5   2019-09-20T00:00:00.000Z
# 6   2013-08-04T00:00:00.000Z
# 7   2017-10-01T00:00:00.000Z
# 8   2020-04-10T00:00:00.000Z
# 9   2020-08-19T00:00:00.000Z
# 10  2013-12-15T00:00:00.000Z
# 11  2019-04-28T00:00:00.000Z
# 12  2020-08-01T00:00:00.000Z
# 13  2019-11-22T00:00:00.000Z
# 14  2020-07-13T00:00:00.000Z
#
#                                                  tags          max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...     21000000.000000
# 1   [mineable, pow, smart-contracts, ethereum-ecos...                 nan
# 2   [payments, stablecoin, asset-backed-stablecoin...                 nan
# 3   [medium-of-exchange, stablecoin, asset-backed-...                 nan
# 4   [marketplace, centralized-exchange, payments, ...    200000000.000000
# 5   [stablecoin, asset-backed-stablecoin, binance-...                 nan
# 6   [medium-of-exchange, enterprise-solutions, arr... 100000000000.000000
# 7   [dpos, pos, platform, research, smart-contract...  45000000000.000000
# 8   [pos, platform, solana-ecosystem, cms-holdings...                 nan
# 9   [substrate, polkadot, binance-chain, polkadot-...                 nan
# 10  [mineable, pow, scrypt, medium-of-exchange, me...                 nan
# 11  [platform, enterprise-solutions, scaling, stat...  10000000000.000000
# 12      [memes, ethereum-ecosystem, doggone-doggerel]                 nan
# 13  [defi, stablecoin, asset-backed-stablecoin, et...                 nan
# 14  [defi, smart-contracts, three-arrows-capital-p...    720000000.000000
#
#        circulating_supply           total_supply  ...  \
# 0         19148118.000000        19148118.000000  ...
# 1        122331659.311500       122331659.311500  ...
# 2      67652203603.291359     69156782826.492813  ...
# 3      51604205337.300781     51604205337.300781  ...
# 4        161337261.090000       161337261.090000  ...
# 5      20003342404.819256     20003342404.819256  ...
# 6      49826021773.000000     99989302361.000000  ...
# 7      34182044152.629002     34854947575.480003  ...
# 8        353283628.280455       511616946.142289  ...
# 9       1116007261.620899      1231430931.946079  ...
# 10    132670764299.894089    132670764299.894089  ...
# 11      8734317475.284929     10000000000.000000  ...
# 12 549063278876301.937500 589735030408322.750000  ...
# 13      6904361908.909560      6904361908.909560  ...
# 14       295663081.152296       404229626.499013  ...
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                        39.284400                 453967194396.690002
# 1                        20.285400                 213729572181.980011
# 2                         6.422100                  69173775912.889999
# 3                         4.897300                  51598280311.879997
# 4                         4.490900                  58656083469.820000
# 5                         1.898600                  20004079326.869999
# 6                         1.676300                  35456569689.260002
# 7                         1.642900                  22787737714.869999
# 8                         1.165700                  17800982144.099998
# 9                         0.810500                   9429683288.160000
# 10                        0.798300                   8410493943.500000
# 11                        0.734900                   8871741321.469999
# 12                        0.674000                   7627064482.220000
# 13                        0.655100                   6904675205.130000
# 14                        0.576800                  14802969572.049999
#
#     quote.USD.tvl    quote.USD.last_updated platform.id platform.name  \
# 0            None  2022-09-11T22:14:00.000Z         nan           NaN
# 1            None  2022-09-11T22:14:00.000Z         nan           NaN
# 2            None  2022-09-11T22:14:00.000Z 1027.000000      Ethereum
# 3            None  2022-09-11T22:14:00.000Z 1027.000000      Ethereum
# 4            None  2022-09-11T22:14:00.000Z         nan           NaN
# 5            None  2022-09-11T22:14:00.000Z 1839.000000           BNB
# 6            None  2022-09-11T22:14:00.000Z         nan           NaN
# 7            None  2022-09-11T22:14:00.000Z         nan           NaN
# 8            None  2022-09-11T22:14:00.000Z         nan           NaN
# 9            None  2022-09-11T22:14:00.000Z         nan           NaN
# 10           None  2022-09-11T22:14:00.000Z         nan           NaN
# 11           None  2022-09-11T22:14:00.000Z         nan           NaN
# 12           None  2022-09-11T22:14:00.000Z 1027.000000      Ethereum
# 13           None  2022-09-11T22:14:00.000Z 1027.000000      Ethereum
# 14           None  2022-09-11T22:14:00.000Z         nan           NaN
#
#     platform.symbol  platform.slug  \
# 0               NaN            NaN
# 1               NaN            NaN
# 2               ETH       ethereum
# 3               ETH       ethereum
# 4               NaN            NaN
# 5               BNB            bnb
# 6               NaN            NaN
# 7               NaN            NaN
# 8               NaN            NaN
# 9               NaN            NaN
# 10              NaN            NaN
# 11              NaN            NaN
# 12              ETH       ethereum
# 13              ETH       ethereum
# 14              NaN            NaN
#
#                         platform.token_address                  timestamp
# 0                                          NaN 2022-09-11 22:16:56.969540
# 1                                          NaN 2022-09-11 22:16:56.969540
# 2   0xdac17f958d2ee523a2206206994597c13d831ec7 2022-09-11 22:16:56.969540
# 3   0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48 2022-09-11 22:16:56.969540
# 4                                          NaN 2022-09-11 22:16:56.969540
# 5                                     BUSD-BD1 2022-09-11 22:16:56.969540
# 6                                          NaN 2022-09-11 22:16:56.969540
# 7                                          NaN 2022-09-11 22:16:56.969540
# 8                                          NaN 2022-09-11 22:16:56.969540
# 9                                          NaN 2022-09-11 22:16:56.969540
# 10                                         NaN 2022-09-11 22:16:56.969540
# 11                                         NaN 2022-09-11 22:16:56.969540
# 12  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce 2022-09-11 22:16:56.969540
# 13  0x6b175474e89094c44da98b954eedeac495271d0f 2022-09-11 22:16:56.969540
# 14                                         NaN 2022-09-11 22:16:56.969540
#
# [15 rows x 36 columns]

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '1cc5375d-420b-4443-80a0-7944e4e21617',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)
    
    
    
    df = pd.json_normalize(data['data'])
    df['timestamp'] = pd.to_datetime('now')
    df
    
    if not os.path.isfile(r'C:\Users\quort\OneDrive\Desktop\Data-Analyst-Portfolio\API.csv'):
        df.to_csv(r'C:\Users\quort\OneDrive\Desktop\Data-Analyst-Portfolio\API.csv', header = 'column_names')
    else:
        df.to_csv(r'C:\Users\quort\OneDrive\Desktop\Data-Analyst-Portfolio\API.csv', mode = 'a', header = False)

# %%
import os
from time import time
from time import sleep

for i in range(333):
    api_runner()
    print('API Runner completed')
    sleep(60) #sleep for one minute
exit()
# Out:
# API Runner completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-2730082703d3> in <module>
#       6     api_runner()
#       7     print('API Runner completed')
# ----> 8     sleep(60) #sleep for one minute
#       9 exit()
#
# KeyboardInterrupt:

# %%
df
# Out:
#       id         name symbol                  slug  num_market_pairs  \
# 0      1      Bitcoin    BTC               bitcoin              9727
# 1   1027     Ethereum    ETH              ethereum              6083
# 2    825       Tether   USDT                tether             39548
# 3   3408     USD Coin   USDC              usd-coin              6158
# 4   1839          BNB    BNB                   bnb              1099
# 5   4687  Binance USD   BUSD           binance-usd              5061
# 6     52          XRP    XRP                   xrp               813
# 7   2010      Cardano    ADA               cardano               568
# 8   5426       Solana    SOL                solana               380
# 9   6636     Polkadot    DOT          polkadot-new               408
# 10    74     Dogecoin   DOGE              dogecoin               560
# 11  3890      Polygon  MATIC               polygon               483
# 12  5994    Shiba Inu   SHIB             shiba-inu               413
# 13  4943          Dai    DAI  multi-collateral-dai              1331
# 14  5805    Avalanche   AVAX             avalanche               311
#
#                   date_added  \
# 0   2013-04-28T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2018-10-08T00:00:00.000Z
# 4   2017-07-25T00:00:00.000Z
# 5   2019-09-20T00:00:00.000Z
# 6   2013-08-04T00:00:00.000Z
# 7   2017-10-01T00:00:00.000Z
# 8   2020-04-10T00:00:00.000Z
# 9   2020-08-19T00:00:00.000Z
# 10  2013-12-15T00:00:00.000Z
# 11  2019-04-28T00:00:00.000Z
# 12  2020-08-01T00:00:00.000Z
# 13  2019-11-22T00:00:00.000Z
# 14  2020-07-13T00:00:00.000Z
#
#                                                  tags          max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...     21000000.000000
# 1   [mineable, pow, smart-contracts, ethereum-ecos...                 nan
# 2   [payments, stablecoin, asset-backed-stablecoin...                 nan
# 3   [medium-of-exchange, stablecoin, asset-backed-...                 nan
# 4   [marketplace, centralized-exchange, payments, ...    200000000.000000
# 5   [stablecoin, asset-backed-stablecoin, binance-...                 nan
# 6   [medium-of-exchange, enterprise-solutions, arr... 100000000000.000000
# 7   [dpos, pos, platform, research, smart-contract...  45000000000.000000
# 8   [pos, platform, solana-ecosystem, cms-holdings...                 nan
# 9   [substrate, polkadot, binance-chain, polkadot-...                 nan
# 10  [mineable, pow, scrypt, medium-of-exchange, me...                 nan
# 11  [platform, enterprise-solutions, scaling, stat...  10000000000.000000
# 12      [memes, ethereum-ecosystem, doggone-doggerel]                 nan
# 13  [defi, stablecoin, asset-backed-stablecoin, et...                 nan
# 14  [defi, smart-contracts, three-arrows-capital-p...    720000000.000000
#
#        circulating_supply           total_supply  ...  \
# 0         19148118.000000        19148118.000000  ...
# 1        122331659.311500       122331659.311500  ...
# 2      67652203603.291359     69156782826.492813  ...
# 3      51604205337.300781     51604205337.300781  ...
# 4        161337261.090000       161337261.090000  ...
# 5      20003342404.819256     20003342404.819256  ...
# 6      49826021773.000000     99989302361.000000  ...
# 7      34182044152.629002     34854947575.480003  ...
# 8        353283628.280455       511616946.142289  ...
# 9       1116007261.620899      1231430931.946079  ...
# 10    132670764299.894089    132670764299.894089  ...
# 11      8734317475.284929     10000000000.000000  ...
# 12 549063278876301.937500 589735030408322.750000  ...
# 13      6904361908.909560      6904361908.909560  ...
# 14       295663081.152296       404229626.499013  ...
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                        39.284400                 453967194396.690002
# 1                        20.285400                 213729572181.980011
# 2                         6.422100                  69173775912.889999
# 3                         4.897300                  51598280311.879997
# 4                         4.490900                  58656083469.820000
# 5                         1.898600                  20004079326.869999
# 6                         1.676300                  35456569689.260002
# 7                         1.642900                  22787737714.869999
# 8                         1.165700                  17800982144.099998
# 9                         0.810500                   9429683288.160000
# 10                        0.798300                   8410493943.500000
# 11                        0.734900                   8871741321.469999
# 12                        0.674000                   7627064482.220000
# 13                        0.655100                   6904675205.130000
# 14                        0.576800                  14802969572.049999
#
#     quote.USD.tvl    quote.USD.last_updated platform.id platform.name  \
# 0            None  2022-09-11T22:14:00.000Z         nan           NaN
# 1            None  2022-09-11T22:14:00.000Z         nan           NaN
# 2            None  2022-09-11T22:14:00.000Z 1027.000000      Ethereum
# 3            None  2022-09-11T22:14:00.000Z 1027.000000      Ethereum
# 4            None  2022-09-11T22:14:00.000Z         nan           NaN
# 5            None  2022-09-11T22:14:00.000Z 1839.000000           BNB
# 6            None  2022-09-11T22:14:00.000Z         nan           NaN
# 7            None  2022-09-11T22:14:00.000Z         nan           NaN
# 8            None  2022-09-11T22:14:00.000Z         nan           NaN
# 9            None  2022-09-11T22:14:00.000Z         nan           NaN
# 10           None  2022-09-11T22:14:00.000Z         nan           NaN
# 11           None  2022-09-11T22:14:00.000Z         nan           NaN
# 12           None  2022-09-11T22:14:00.000Z 1027.000000      Ethereum
# 13           None  2022-09-11T22:14:00.000Z 1027.000000      Ethereum
# 14           None  2022-09-11T22:14:00.000Z         nan           NaN
#
#     platform.symbol  platform.slug  \
# 0               NaN            NaN
# 1               NaN            NaN
# 2               ETH       ethereum
# 3               ETH       ethereum
# 4               NaN            NaN
# 5               BNB            bnb
# 6               NaN            NaN
# 7               NaN            NaN
# 8               NaN            NaN
# 9               NaN            NaN
# 10              NaN            NaN
# 11              NaN            NaN
# 12              ETH       ethereum
# 13              ETH       ethereum
# 14              NaN            NaN
#
#                         platform.token_address                  timestamp
# 0                                          NaN 2022-09-11 22:17:03.666919
# 1                                          NaN 2022-09-11 22:17:03.666919
# 2   0xdac17f958d2ee523a2206206994597c13d831ec7 2022-09-11 22:17:03.666919
# 3   0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48 2022-09-11 22:17:03.666919
# 4                                          NaN 2022-09-11 22:17:03.666919
# 5                                     BUSD-BD1 2022-09-11 22:17:03.666919
# 6                                          NaN 2022-09-11 22:17:03.666919
# 7                                          NaN 2022-09-11 22:17:03.666919
# 8                                          NaN 2022-09-11 22:17:03.666919
# 9                                          NaN 2022-09-11 22:17:03.666919
# 10                                         NaN 2022-09-11 22:17:03.666919
# 11                                         NaN 2022-09-11 22:17:03.666919
# 12  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce 2022-09-11 22:17:03.666919
# 13  0x6b175474e89094c44da98b954eedeac495271d0f 2022-09-11 22:17:03.666919
# 14                                         NaN 2022-09-11 22:17:03.666919
#
# [15 rows x 36 columns]

# %%
temp = pd.read_csv(r'C:\Users\quort\OneDrive\Desktop\Data-Analyst-Portfolio\API.csv')
temp
# Out:
#       Unnamed: 0    id       name symbol                  slug  \
# 0              0     1    Bitcoin    BTC               bitcoin
# 1              1  1027   Ethereum    ETH              ethereum
# 2              2   825     Tether   USDT                tether
# 3              3  3408   USD Coin   USDC              usd-coin
# 4              4  1839        BNB    BNB                   bnb
# ...          ...   ...        ...    ...                   ...
# 5020          10    74   Dogecoin   DOGE              dogecoin
# 5021          11  3890    Polygon  MATIC               polygon
# 5022          12  5994  Shiba Inu   SHIB             shiba-inu
# 5023          13  4943        Dai    DAI  multi-collateral-dai
# 5024          14  5805  Avalanche   AVAX             avalanche
#
#       num_market_pairs                date_added  \
# 0                 9727  2013-04-28T00:00:00.000Z
# 1                 6083  2015-08-07T00:00:00.000Z
# 2                39521  2015-02-25T00:00:00.000Z
# 3                 6156  2018-10-08T00:00:00.000Z
# 4                 1098  2017-07-25T00:00:00.000Z
# ...                ...                       ...
# 5020               560  2013-12-15T00:00:00.000Z
# 5021               483  2019-04-28T00:00:00.000Z
# 5022               413  2020-08-01T00:00:00.000Z
# 5023              1331  2019-11-22T00:00:00.000Z
# 5024               311  2020-07-13T00:00:00.000Z
#
#                                                    tags         max_supply  \
# 0     ['mineable', 'pow', 'sha-256', 'store-of-value...    21000000.000000
# 1     ['mineable', 'pow', 'smart-contracts', 'ethere...                nan
# 2     ['payments', 'stablecoin', 'asset-backed-stabl...                nan
# 3     ['medium-of-exchange', 'stablecoin', 'asset-ba...                nan
# 4     ['marketplace', 'centralized-exchange', 'payme...   200000000.000000
# ...                                                 ...                ...
# 5020  ['mineable', 'pow', 'scrypt', 'medium-of-excha...                nan
# 5021  ['platform', 'enterprise-solutions', 'scaling'... 10000000000.000000
# 5022  ['memes', 'ethereum-ecosystem', 'doggone-dogge...                nan
# 5023  ['defi', 'stablecoin', 'asset-backed-stablecoi...                nan
# 5024  ['defi', 'smart-contracts', 'three-arrows-capi...   720000000.000000
#
#          circulating_supply  ...  quote.USD.market_cap_dominance  \
# 0           19146787.000000  ...                       39.061700
# 1          122315793.436500  ...                       20.103800
# 2        67546203603.441360  ...                        6.445600
# 3        51660240439.237389  ...                        4.926900
# 4          161337261.090000  ...                        4.521300
# ...                     ...  ...                             ...
# 5020    132670764299.894073  ...                        0.798300
# 5021      8734317475.284929  ...                        0.734900
# 5022 549063278876301.937500  ...                        0.674000
# 5023      6904361908.909560  ...                        0.655100
# 5024       295663081.152296  ...                        0.576800
#
#       quote.USD.fully_diluted_market_cap  quote.USD.tvl  \
# 0                    449104821892.190002            nan
# 1                    210755289147.269989            nan
# 2                     69178675300.990005            nan
# 3                     51659595262.660004            nan
# 4                     58767197830.339996            nan
# ...                                  ...            ...
# 5020                   8410493943.500000            nan
# 5021                   8871741321.469999            nan
# 5022                   7627064482.220000            nan
# 5023                   6904675205.130000            nan
# 5024                  14802969572.049999            nan
#
#         quote.USD.last_updated  platform.id  platform.name platform.symbol  \
# 0     2022-09-10T17:03:00.000Z          nan            NaN             NaN
# 1     2022-09-10T17:03:00.000Z          nan            NaN             NaN
# 2     2022-09-10T17:03:00.000Z  1027.000000       Ethereum             ETH
# 3     2022-09-10T17:03:00.000Z  1027.000000       Ethereum             ETH
# 4     2022-09-10T17:03:00.000Z          nan            NaN             NaN
# ...                        ...          ...            ...             ...
# 5020  2022-09-11T22:14:00.000Z          nan            NaN             NaN
# 5021  2022-09-11T22:14:00.000Z          nan            NaN             NaN
# 5022  2022-09-11T22:14:00.000Z  1027.000000       Ethereum             ETH
# 5023  2022-09-11T22:14:00.000Z  1027.000000       Ethereum             ETH
# 5024  2022-09-11T22:14:00.000Z          nan            NaN             NaN
#
#       platform.slug                      platform.token_address  \
# 0               NaN                                         NaN
# 1               NaN                                         NaN
# 2          ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3          ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4               NaN                                         NaN
# ...             ...                                         ...
# 5020            NaN                                         NaN
# 5021            NaN                                         NaN
# 5022       ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 5023       ethereum  0x6b175474e89094c44da98b954eedeac495271d0f
# 5024            NaN                                         NaN
#
#                        timestamp
# 0     2022-09-10 17:04:56.319851
# 1     2022-09-10 17:04:56.319851
# 2     2022-09-10 17:04:56.319851
# 3     2022-09-10 17:04:56.319851
# 4     2022-09-10 17:04:56.319851
# ...                          ...
# 5020  2022-09-11 22:17:03.666919
# 5021  2022-09-11 22:17:03.666919
# 5022  2022-09-11 22:17:03.666919
# 5023  2022-09-11 22:17:03.666919
# 5024  2022-09-11 22:17:03.666919
#
# [5025 rows x 37 columns]

# %%
df3 = temp.groupby('name', sort = False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3
# Out:
#              quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                         0.002707                      1.001294
# Ethereum                       -0.142400                      1.983612
# Tether                         -0.000033                      0.001951
# USD Coin                       -0.000775                     -0.002769
# BNB                            -0.018259                      0.316113
# Binance USD                     0.002511                     -0.016010
# XRP                             0.053686                      0.099167
# Cardano                        -0.112943                      0.237951
# Solana                         -0.087233                      1.775698
# Polkadot                       -0.137286                      0.461774
# Dogecoin                       -0.120658                     -0.013561
# Polygon                        -0.150341                     -0.090151
# Shiba Inu                      -0.118412                     -0.777485
# Dai                            -0.005319                     -0.016002
# Avalanche                      -0.090506                      1.270560
#
#              quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# name
# Bitcoin                         8.876179                    -10.235200
# Ethereum                       12.604554                     -7.630605
# Tether                          0.021468                     -0.004691
# USD Coin                       -0.014382                     -0.003083
# BNB                             5.840945                     -9.007318
# Binance USD                    -0.023620                     -0.001300
# XRP                             7.526122                     -4.977409
# Cardano                         2.315344                     -4.132855
# Solana                         11.151638                    -19.336395
# Polkadot                        6.340614                    -17.499227
# Dogecoin                        1.375042                    -10.260733
# Polygon                         0.625409                     -2.897788
# Shiba Inu                       1.878565                      4.056721
# Dai                            -0.041978                      0.016237
# Avalanche                       8.370831                    -29.145431
#
#              quote.USD.percent_change_60d  quote.USD.percent_change_90d
# name
# Bitcoin                          9.751614                     -7.874793
# Ethereum                        63.317150                     42.170256
# Tether                           0.095428                      0.151721
# USD Coin                        -0.029357                     -0.033399
# BNB                             31.068317                     29.794135
# Binance USD                     -0.064124                     -0.088844
# XRP                             12.454893                     11.655561
# Cardano                         21.251753                      7.431308
# Solana                           4.985370                     24.068115
# Polkadot                        22.541116                      9.158429
# Dogecoin                         6.440957                     14.539858
# Polygon                         56.480685                    102.531831
# Shiba Inu                       26.924923                     57.539491
# Dai                             -0.037626                     -0.060250
# Avalanche                       15.111815                     26.488773

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin    quote.USD.percent_change_1h      0.002707
#            quote.USD.percent_change_24h     1.001294
#            quote.USD.percent_change_7d      8.876179
#            quote.USD.percent_change_30d   -10.235200
#            quote.USD.percent_change_60d     9.751614
#                                              ...
# Avalanche  quote.USD.percent_change_24h     1.270560
#            quote.USD.percent_change_7d      8.370831
#            quote.USD.percent_change_30d   -29.145431
#            quote.USD.percent_change_60d    15.111815
#            quote.USD.percent_change_90d    26.488773
# Length: 90, dtype: float64

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
df5 = df4.to_frame(name = 'values')
df5
# Out:
#                                            values
# name
# Bitcoin   quote.USD.percent_change_1h    0.002707
#           quote.USD.percent_change_24h   1.001294
#           quote.USD.percent_change_7d    8.876179
#           quote.USD.percent_change_30d -10.235200
#           quote.USD.percent_change_60d   9.751614
# ...                                           ...
# Avalanche quote.USD.percent_change_24h   1.270560
#           quote.USD.percent_change_7d    8.370831
#           quote.USD.percent_change_30d -29.145431
#           quote.USD.percent_change_60d  15.111815
#           quote.USD.percent_change_90d  26.488773
#
# [90 rows x 1 columns]

# %%
df5.count()
# Out:
# values    90
# dtype: int64

# %%
index=pd.Index(range(df5.count()['values']))
df6 = df5.reset_index()
df7 = df6.rename(columns = {'level_1':'percent_change'})
df7
# Out:
#          name                percent_change     values
# 0     Bitcoin   quote.USD.percent_change_1h   0.002707
# 1     Bitcoin  quote.USD.percent_change_24h   1.001294
# 2     Bitcoin   quote.USD.percent_change_7d   8.876179
# 3     Bitcoin  quote.USD.percent_change_30d -10.235200
# 4     Bitcoin  quote.USD.percent_change_60d   9.751614
# ..        ...                           ...        ...
# 85  Avalanche  quote.USD.percent_change_24h   1.270560
# 86  Avalanche   quote.USD.percent_change_7d   8.370831
# 87  Avalanche  quote.USD.percent_change_30d -29.145431
# 88  Avalanche  quote.USD.percent_change_60d  15.111815
# 89  Avalanche  quote.USD.percent_change_90d  26.488773
#
# [90 rows x 3 columns]

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'], ['1h', '24h', '7d','30d', '60d', '90d'])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='percent_change', y = 'values', hue = 'name', data = df7, kind = 'point')

# %%
df9 = temp[['name', 'quote.USD.price','timestamp']] 
df9 = df9.query("name == 'Bitcoin'")
df9
# Out:
#          name  quote.USD.price                   timestamp
# 0     Bitcoin     21385.943900  2022-09-10 17:04:56.319851
# 15    Bitcoin     21379.173908  2022-09-10 17:06:15.868653
# 30    Bitcoin     21691.574082  2022-09-11 16:24:20.675942
# 45    Bitcoin     21689.914188  2022-09-11 16:25:21.101541
# 60    Bitcoin     21672.726351  2022-09-11 16:26:21.338538
# ...       ...              ...                         ...
# 4950  Bitcoin     21576.238631  2022-09-11 21:55:08.421749
# 4965  Bitcoin     21566.127904  2022-09-11 21:56:08.636252
# 4980  Bitcoin     21546.838190  2022-09-11 21:57:08.914252
# 4995  Bitcoin     21550.313149  2022-09-11 21:58:09.281752
# 5010  Bitcoin     21617.485447  2022-09-11 22:17:03.666919
#
# [335 rows x 3 columns]

# %%
sns.set(style = 'darkgrid')

sns.lineplot(x='timestamp', y = 'quote.USD.price', data = df9)
