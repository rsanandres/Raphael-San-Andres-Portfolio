# %% [markdown]
# # NOTE: I dont want to do a neural network here even though it may be better. I am trying to use something that is not DL-based.

# %% [markdown]
# ## Libraries

# %%
# !pip install spicy
# Out:
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\quort\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\quort\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\quort\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\quort\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\quort\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\quort\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\quort\anaconda3\lib\site-packages)
# Collecting spicy
#   Downloading spicy-0.16.0-py2.py3-none-any.whl (1.7 kB)
# Requirement already satisfied: scipy in c:\users\quort\anaconda3\lib\site-packages (from spicy) (1.7.3)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in c:\users\quort\anaconda3\lib\site-packages (from scipy->spicy) (1.22.2)
# Installing collected packages: spicy
# Successfully installed spicy-0.16.0

# %%
import csv
import pandas as pd
import seaborn as sns
import numpy as np

from sklearn.metrics.pairwise import cosine_similarity
from scipy import sparse

# %% [markdown]
# ## Papers that helped me

# %% [markdown]
# [Big Data with Clustering](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7924475/#:~:text=common%20graph%20algorithms.-,Clustering%20big%20data,useful%20patterns%20within%20a%20dataset.) <br />
# [Clustering Algorithms](http://www.cs.newpaltz.edu/~lik/publications/books/K29224_C016.pdf) <br />
# [User Based vs Item Based](https://www.diva-portal.org/smash/get/diva2:1111865/FULLTEXT01.pdf)

# %% [markdown]
# ## Load Dataset

# %% [markdown]
# [Dataset](https://cseweb.ucsd.edu/~jmcauley/datasets.html#twitch)

# %% [raw]
# "Start and stop times are provided as integers and represent periods of 10 minutes. Stream ID could be used to retrieve a single broadcast segment from a streamer (not used in our work).
# - User ID (anonymized) [15.5 million users]
# - Stream ID [465k streamers]
# - Streamer username
# - Time start
# - Time stop"

# %%
header1 = ["User ID", "Stream ID", "Streamer Username", "Time Start", "Time Stop"]

df = pd.read_csv("full_a.csv", nrows = 1e6, header = None, names = header1)
df[df['User ID'] == 2]
# Out:
#     User ID    Stream ID Streamer Username  Time Start  Time Stop
# 44        2  34302820672            mattie        4969       4974
# 45        2  34342297872         goldglove        5334       5337
# 46        2  34355796976         goldglove        5476       5478
# 47        2  34362322016       rtgamecrowd        5554       5566
# 48        2  34396737984       carlosstory        5914       5918
# 49        2  34396886576            witwix        5910       5919
# 50        2  34410905408            witwix        6073       6076
# 51        2  34411115296            witwix        6077       6081

# %%
#Check for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
#This is for this dataset
#Full Dataset has 15million users

len(df['User ID'].unique())
# Out:
# 34374

# %% [markdown]
# ## Exploratory Data Analysis

# %% [raw]
# Thinking through what things I can discover from this EDA:
# - What users are loyal?
# - Average amount of streamers per viewer?
# - How many times does a user visit a particular streamer?
# - How long was each session that a viewer watched a streamer? Are there vieweres with >2 hour sessions? How about 7?

# %%
#How many streamers do people usually watch?
df['Streamers Watched'] = df.groupby(['User ID'])['Streamer Username'].transform('count')
df
# Out:
#         User ID    Stream ID Streamer Username  Time Start  Time Stop  \
# 0             1  33827518864             lirik          25         26
# 1             1  33870289680       giantwaffle         457        460
# 2             1  33876317008     blacklisted86         471        472
# 3             1  33882713200       cohhcarnage         544        550
# 4             1  33885628720             lirik         586        588
# ...         ...          ...               ...         ...        ...
# 999995    34374  33885521536       piazztwitch         571        573
# 999996    34374  33885545376          efesto96         571        573
# 999997    34374  33887753632              tfue         575        576
# 999998    34374  33888568352     therealmarzaa         578        579
# 999999    34374  33888952608           pow3rtv         579        581
#
#         Streamers Watched
# 0                      44
# 1                      44
# 2                      44
# 3                      44
# 4                      44
# ...                   ...
# 999995                 12
# 999996                 12
# 999997                 12
# 999998                 12
# 999999                 12
#
# [1000000 rows x 6 columns]

# %%
#Checking to make sure
df[df['User ID'] == 3354]
# Out:
#         User ID    Stream ID Streamer Username  Time Start  Time Stop  \
# 99995      3354  33853518400        handongsuk         255        256
# 99996      3354  33853894096            horusb         254        255
# 99997      3354  33879776560       pacific8815         517        518
# 99998      3354  33881001328        nanajam777         517        519
# 99999      3354  33881473696          yapyap30         538        539
# 100000     3354  33883287552            horusb         550        551
# 100001     3354  33899308512             wkgml         686        687
# 100002     3354  33925462480        handongsuk         975        976
# 100003     3354  33938737472       lol_madlife        1120       1122
# 100004     3354  33992785920        nanajam777        1682       1683
# 100005     3354  33995138896          yapyap30        1684       1687
# 100006     3354  33996274688        handongsuk        1689       1690
# 100007     3354  33996956992            horusb        1690       1691
# 100008     3354  34033518624           hwkang2        2120       2121
# 100009     3354  34034545232            horusb        2123       2124
# 100010     3354  34066719472      dogswellfish        2526       2528
# 100011     3354  34114432432        handongsuk        2972       2973
# 100012     3354  34137313504           hwkang2        3274       3276
# 100013     3354  34148864368            109ace        3411       3412
# 100014     3354  34164183424      hanryang1125        3556       3557
# 100015     3354  34165750096            horusb        3555       3556
# 100016     3354  34178853632         mister903        3673       3674
# 100017     3354  34191654624      dogswellfish        3842       3844
# 100018     3354  34205758192          yapyap30        3980       3981
# 100019     3354  34218370656           hwkang2        4119       4120
# 100020     3354  34228689328      dogswellfish        4276       4277
# 100021     3354  34231995984        handongsuk        4277       4278
# 100022     3354  34244099472           hwkang2        4420       4421
# 100023     3354  34253369616      dogswellfish        4527       4528
# 100024     3354  34257439664       pacific8815        4528       4529
# 100025     3354  34258546848           hwkang2        4540       4543
# 100026     3354  34275872896        handongsuk        4695       4697
# 100027     3354  34287948992      rooftopcat99        4838       4840
# 100028     3354  34345895136        woowakgood        5417       5418
# 100029     3354  34346591760       lol_madlife        5412       5413
# 100030     3354  34347065456             ajehr        5414       5417
# 100031     3354  34360284592        woowakgood        5566       5569
# 100032     3354  34365527440      dogswellfish        5583       5584
# 100033     3354  34368689200      dogswellfish        5633       5635
# 100034     3354  34372528272       pacific8815        5663       5664
# 100035     3354  34400494576         rhdgurwns        5982       5983
#
#         Streamers Watched
# 99995                  41
# 99996                  41
# 99997                  41
# 99998                  41
# 99999                  41
# 100000                 41
# 100001                 41
# 100002                 41
# 100003                 41
# 100004                 41
# 100005                 41
# 100006                 41
# 100007                 41
# 100008                 41
# 100009                 41
# 100010                 41
# 100011                 41
# 100012                 41
# 100013                 41
# 100014                 41
# 100015                 41
# 100016                 41
# 100017                 41
# 100018                 41
# 100019                 41
# 100020                 41
# 100021                 41
# 100022                 41
# 100023                 41
# 100024                 41
# 100025                 41
# 100026                 41
# 100027                 41
# 100028                 41
# 100029                 41
# 100030                 41
# 100031                 41
# 100032                 41
# 100033                 41
# 100034                 41
# 100035                 41

# %%
sns.histplot(df['Streamers Watched'])
# Out:
# <AxesSubplot:xlabel='Streamers Watched', ylabel='Count'>

# %%
temp = df[df['Streamers Watched'] < 50]['Streamers Watched']
sns.histplot(temp)
# Out:
# <AxesSubplot:xlabel='Streamers Watched', ylabel='Count'>

# %%
visits = df.groupby(['Streamer Username', "User ID"])['User ID'].size().reset_index(name="Visits")
visits
# Out:
#        Streamer Username  User ID  Visits
# 0             001anthony    24208       1
# 1              001pickle    27675       1
# 2         007kingchannel     4630       1
# 3         007kingchannel    10378       1
# 4                007zeus     5538       4
# ...                  ...      ...     ...
# 491212           zzzzydh    11512       1
# 491213           zzzzydh    26135       1
# 491214           zzzzydh    31153      11
# 491215           zzzzz87    13070       1
# 491216        zzzzzzzach    10448       1
#
# [491217 rows x 3 columns]

# %%
df = df.merge(visits, on = ["Streamer Username", "User ID"], how = "left")

# %%
df
# Out:
#         User ID    Stream ID Streamer Username  Time Start  Time Stop  \
# 0             1  33827518864             lirik          25         26
# 1             1  33870289680       giantwaffle         457        460
# 2             1  33876317008     blacklisted86         471        472
# 3             1  33882713200       cohhcarnage         544        550
# 4             1  33885628720             lirik         586        588
# ...         ...          ...               ...         ...        ...
# 999995    34374  33885521536       piazztwitch         571        573
# 999996    34374  33885545376          efesto96         571        573
# 999997    34374  33887753632              tfue         575        576
# 999998    34374  33888568352     therealmarzaa         578        579
# 999999    34374  33888952608           pow3rtv         579        581
#
#         Streamers Watched  Visits
# 0                      44       9
# 1                      44       2
# 2                      44       5
# 3                      44       3
# 4                      44       9
# ...                   ...     ...
# 999995                 12       1
# 999996                 12       1
# 999997                 12       1
# 999998                 12       1
# 999999                 12       2
#
# [1000000 rows x 7 columns]

# %%
#What are the people who have loyal people in their streams?
df[df['Visits'] > 20]
# Out:
#         User ID    Stream ID Streamer Username  Time Start  Time Stop  \
# 903          14  33837280576    admiralbulldog          87         93
# 906          14  33851487648    admiralbulldog         229        238
# 910          14  33911487376    admiralbulldog         805        813
# 916          14  33950256512    admiralbulldog        1235       1248
# 927          14  34020486352    admiralbulldog        1952       1968
# ...         ...          ...               ...         ...        ...
# 998480    34311  34335480048              p0me        5306       5320
# 998482    34311  34340808480              p0me        5324       5334
# 998484    34311  34348751120              p0me        5435       5444
# 998489    34311  34384956672              p0me        5772       5782
# 998493    34311  34394835856              p0me        5890       5904
#
#         Streamers Watched  Visits
# 903                    98      26
# 906                    98      26
# 910                    98      26
# 916                    98      26
# 927                    98      26
# ...                   ...     ...
# 998480                100      24
# 998482                100      24
# 998484                100      24
# 998489                100      24
# 998493                100      24
#
# [8076 rows x 7 columns]

# %%
## Top Streamers

temp = df[df['Visits'] > 10]
temp = temp[['Streamer Username', 'User ID']]
temp = temp.drop_duplicates()
temp = temp.groupby(['Streamer Username']).size().reset_index(name="Loyal Viewers").sort_values(by = ['Loyal Viewers'])
temp[temp['Loyal Viewers'] > 5]
# Out:
#      Streamer Username  Loyal Viewers
# 482            dkwl025              6
# 1106        kutcherlol              6
# 2149        vkingplays              6
# 1326         mirage720              6
# 1074            ko0416              6
# ...                ...            ...
# 2226             xqcow             68
# 1446             ninja             68
# 562             elwind             69
# 1466       noway4u_sir             76
# 1337          mithrain             93
#
# [202 rows x 2 columns]

# %%
df['Watch Time'] = df['Time Stop'] - df['Time Start']
df
# Out:
#         User ID    Stream ID Streamer Username  Time Start  Time Stop  \
# 0             1  33827518864             lirik          25         26
# 1             1  33870289680       giantwaffle         457        460
# 2             1  33876317008     blacklisted86         471        472
# 3             1  33882713200       cohhcarnage         544        550
# 4             1  33885628720             lirik         586        588
# ...         ...          ...               ...         ...        ...
# 999995    34374  33885521536       piazztwitch         571        573
# 999996    34374  33885545376          efesto96         571        573
# 999997    34374  33887753632              tfue         575        576
# 999998    34374  33888568352     therealmarzaa         578        579
# 999999    34374  33888952608           pow3rtv         579        581
#
#         Streamers Watched  Visits  Watch Time
# 0                      44       9           1
# 1                      44       2           3
# 2                      44       5           1
# 3                      44       3           6
# 4                      44       9           2
# ...                   ...     ...         ...
# 999995                 12       1           2
# 999996                 12       1           2
# 999997                 12       1           1
# 999998                 12       1           1
# 999999                 12       2           2
#
# [1000000 rows x 8 columns]

# %%
#1 Time Watched = 10 minutes

#looking for streamers who have at least one viewer watch for more than 7 hours
temp = df[df['Watch Time'] > 42] 
len(temp['Streamer Username'].unique())
# Out:
# 264

# %%
list(temp['Streamer Username'].unique())
# Out:
# ['greekgodx',
#  'thijs',
#  'esl_dota2',
#  'xargon0731',
#  'asiagodtonegg3be0',
#  'a541021',
#  'asmongold',
#  'gn_gg',
#  'summit1g',
#  'tfue',
#  'koil',
#  'dota2ruhub',
#  'fpsthailand',
#  'amouranth',
#  'burkeblack',
#  'axtlol',
#  'c_a_k_e',
#  'zero',
#  'mandiocaa1',
#  'gaules',
#  'overwatchleague',
#  'dasmehdi',
#  'quin69',
#  'solary',
#  'roshtein',
#  'veelaprincess',
#  'agraelus',
#  'deriumspokemon',
#  'kingrichard',
#  'twistonfire',
#  'toqtir',
#  'vlad_boroda',
#  'riotgames',
#  'reckful',
#  'fifatargrean',
#  'anniefuchsia',
#  'sodapoppin',
#  'theno1alex',
#  'maximilian_dood',
#  'playhearthstone',
#  'manvsgame',
#  'welovegames',
#  'stray228',
#  'timstr8juggin',
#  'overpow',
#  'fps_shaka',
#  'handongsuk',
#  'saddummy',
#  'www0606',
#  'kimdoe',
#  'lck_korea',
#  'dogswellfish',
#  'lol_ambition',
#  'seals311',
#  'majinobama',
#  'alanzoka',
#  'grandgrant',
#  'sutanmi',
#  'kabeosyama',
#  'dansgaming',
#  'zrush',
#  'uzra',
#  'failverde',
#  'jinu6734',
#  'lexveldhuis',
#  'hitujiha',
#  'forsen',
#  'widdz',
#  'unorthodogg',
#  'pokemonbaribarijapan',
#  'mdldisney',
#  'nana803',
#  'qkfhzhal',
#  'rockmygaming',
#  'rebirthztv',
#  'guit88man',
#  'warcraft',
#  'gugu2525',
#  'xqcow',
#  'pondelinp',
#  'hellboyshow',
#  'rakin',
#  'ogamingsc2',
#  'hutnik',
#  'patopapao',
#  'tanukininja',
#  'harnaisxsumire666',
#  'admiralbahroo',
#  'royalphunk',
#  'imls',
#  'eisenp3lz',
#  'obgkatiekat',
#  'ch1ckenkun',
#  'bulmyeol_tv',
#  'nightmareoneshot',
#  'faceittv',
#  'symfuhny',
#  'albislol',
#  'chocolatecolor',
#  'grass51008',
#  'imaqtpie',
#  'mrzulin',
#  'buddha',
#  'akaruu',
#  'rainbow6',
#  'livibee',
#  'rotmgfloflorian',
#  'ogaminglol',
#  'cocopopp671',
#  'matrixis',
#  'derwegrenner',
#  'dreadztv',
#  'timpani',
#  'angelus_esport',
#  'zerator',
#  'kyle',
#  'riotgamesjp',
#  'stormlingx',
#  'criken',
#  'cohhcarnage',
#  'vanderforge',
#  'lirik',
#  'vader',
#  'squirrelchen',
#  'ninja',
#  'fl0m',
#  'uberhaxornova',
#  'swifty',
#  'cuppcaake',
#  'castro_1021',
#  'pmsproxy',
#  'theuberelite',
#  'soaryn',
#  'drdisrespect',
#  'loltyler1',
#  'selfmadetv',
#  'sips_',
#  'woowakgood',
#  'ron_plays_games',
#  'vgtv_ultimate',
#  'flanalistaa',
#  'quepavadaspro',
#  'cyberclasher',
#  'danucd',
#  'japan_asmr',
#  'distortion2',
#  'cruciangaming',
#  'kimdduddi',
#  'superftlol',
#  'dragon3652',
#  'nicewigg',
#  'jovirone',
#  'aurateur',
#  'tsm_theoddone',
#  'frogman1',
#  'methodjosh',
#  '360chrism',
#  'atamanman',
#  'nightblue3',
#  'esl_joindotared',
#  'h2p_gucio',
#  'rrrrat',
#  'gorgc',
#  'spackoarzt',
#  'mailand',
#  'shivfps',
#  'trainwreckstv',
#  'maybeshe',
#  'germenchrestream',
#  'wtf_winds123',
#  'anis13k',
#  'hyper2374',
#  'misusingtv',
#  'thekller',
#  'xenoxga',
#  'pandagirl91',
#  'alohadancetv',
#  'pokelawls',
#  'xgladd',
#  '0pi_m8',
#  'bobross',
#  'angrypug',
#  'polt',
#  'casinodaddy',
#  'btscsgo',
#  '1ceprime',
#  'goldglove',
#  'brahemic',
#  'gamesdonequick',
#  'blondbear',
#  'lestream',
#  'marymaybe',
#  'paxelol',
#  'pago3',
#  'blastproseries',
#  'rhobalas_lol',
#  'twitchpresentsfr',
#  'sequisha',
#  'naseongkim',
#  'bobek_zklobouku',
#  'hermanel',
#  'calebhart42',
#  'alaskansavage',
#  'hydramist',
#  'josephb93',
#  'crackdel29',
#  'xanogames',
#  'esfandtv',
#  'superjj102',
#  'iks_slon',
#  'bast_50',
#  'esquadraomav',
#  'igutan',
#  'yumyumyu77',
#  'streamlab',
#  'acolytesynpai',
#  'icyrayne',
#  'teamvash',
#  'relaxbeats',
#  'kiitlock',
#  'vega_lim',
#  'whoozaa',
#  'makemorelove',
#  'cnaps',
#  'nightmarecwb',
#  'jonahveil',
#  'araiance',
#  'yapyap30',
#  'strippin',
#  'angryjoeshow',
#  'nanajam777',
#  'coldzin',
#  'cutedog_',
#  'shanksy',
#  'p4wnyhof',
#  'mrfreshasian',
#  'lospollostv',
#  'itsfreakinethan',
#  'noizen',
#  'hanryang1125',
#  'sd0323',
#  'meloudya',
#  'lord_kebun',
#  'anchorstar',
#  'shuteye_orange',
#  'suisai',
#  'melharucos',
#  'smoke',
#  'dakotaz',
#  'stormviewlive',
#  'xargoftw',
#  'draskyl',
#  'adamvseverything',
#  'riotgamesbrazil',
#  'silvername',
#  'norkdorf',
#  'liuliu_wei',
#  'valerie_rayne',
#  'wan_ke',
#  'nixjke',
#  'jmjdoc',
#  'junioranitv',
#  'syaruru3',
#  'natsumiii']

# %%
#Streamers who have at least one viewer watch them for more than 2 hours
temp = df[df['Watch Time'] > 12] 
len(temp['Streamer Username'].unique())
# Out:
# 8705

# %%
df
# Out:
#         User ID    Stream ID Streamer Username  Time Start  Time Stop  \
# 0             1  33827518864             lirik          25         26
# 1             1  33870289680       giantwaffle         457        460
# 2             1  33876317008     blacklisted86         471        472
# 3             1  33882713200       cohhcarnage         544        550
# 4             1  33885628720             lirik         586        588
# ...         ...          ...               ...         ...        ...
# 999995    34374  33885521536       piazztwitch         571        573
# 999996    34374  33885545376          efesto96         571        573
# 999997    34374  33887753632              tfue         575        576
# 999998    34374  33888568352     therealmarzaa         578        579
# 999999    34374  33888952608           pow3rtv         579        581
#
#         Streamers Watched  Visits  Watch Time
# 0                      44       9           1
# 1                      44       2           3
# 2                      44       5           1
# 3                      44       3           6
# 4                      44       9           2
# ...                   ...     ...         ...
# 999995                 12       1           2
# 999996                 12       1           2
# 999997                 12       1           1
# 999998                 12       1           1
# 999999                 12       2           2
#
# [1000000 rows x 8 columns]

# %%
#adding percentage time watched
temp = df.groupby('User ID').agg(Sum=('Watch Time','sum')).reset_index()#Calculate sum
temp = df.merge(temp, on = ["User ID"], how = "left")
temp = temp.rename(columns = {"Sum": "User Total Time Watching Streams"})
a = temp.groupby(["User ID",'Streamer Username', 'User Total Time Watching Streams'])['Watch Time'].sum().reset_index(name="Total Time Watching Streamer")
a['Percentage of Time Watching Streamer'] = (a['Total Time Watching Streamer']/a['User Total Time Watching Streams']) * 100.
temp = temp.merge(a, on = ["User ID", "Streamer Username", "User Total Time Watching Streams"], how = "left")
temp
# Out:
#         User ID    Stream ID Streamer Username  Time Start  Time Stop  \
# 0             1  33827518864             lirik          25         26
# 1             1  33870289680       giantwaffle         457        460
# 2             1  33876317008     blacklisted86         471        472
# 3             1  33882713200       cohhcarnage         544        550
# 4             1  33885628720             lirik         586        588
# ...         ...          ...               ...         ...        ...
# 999995    34374  33885521536       piazztwitch         571        573
# 999996    34374  33885545376          efesto96         571        573
# 999997    34374  33887753632              tfue         575        576
# 999998    34374  33888568352     therealmarzaa         578        579
# 999999    34374  33888952608           pow3rtv         579        581
#
#         Streamers Watched  Visits  Watch Time  \
# 0                      44       9           1
# 1                      44       2           3
# 2                      44       5           1
# 3                      44       3           6
# 4                      44       9           2
# ...                   ...     ...         ...
# 999995                 12       1           2
# 999996                 12       1           2
# 999997                 12       1           1
# 999998                 12       1           1
# 999999                 12       2           2
#
#         User Total Time Watching Streams  Total Time Watching Streamer  \
# 0                                    124                            23
# 1                                    124                             4
# 2                                    124                            10
# 3                                    124                             9
# 4                                    124                            23
# ...                                  ...                           ...
# 999995                                16                             2
# 999996                                16                             2
# 999997                                16                             1
# 999998                                16                             1
# 999999                                16                             3
#
#         Percentage of Time Watching Streamer
# 0                                  18.548387
# 1                                   3.225806
# 2                                   8.064516
# 3                                   7.258065
# 4                                  18.548387
# ...                                      ...
# 999995                             12.500000
# 999996                             12.500000
# 999997                              6.250000
# 999998                              6.250000
# 999999                             18.750000
#
# [1000000 rows x 11 columns]

# %%
df = temp
df
#I am going to use either Total Time watching Streamer or Percentage of Time watching streamer as the "Rating" metric
# Out:
#         User ID    Stream ID Streamer Username  Time Start  Time Stop  \
# 0             1  33827518864             lirik          25         26
# 1             1  33870289680       giantwaffle         457        460
# 2             1  33876317008     blacklisted86         471        472
# 3             1  33882713200       cohhcarnage         544        550
# 4             1  33885628720             lirik         586        588
# ...         ...          ...               ...         ...        ...
# 999995    34374  33885521536       piazztwitch         571        573
# 999996    34374  33885545376          efesto96         571        573
# 999997    34374  33887753632              tfue         575        576
# 999998    34374  33888568352     therealmarzaa         578        579
# 999999    34374  33888952608           pow3rtv         579        581
#
#         Streamers Watched  Visits  Watch Time  \
# 0                      44       9           1
# 1                      44       2           3
# 2                      44       5           1
# 3                      44       3           6
# 4                      44       9           2
# ...                   ...     ...         ...
# 999995                 12       1           2
# 999996                 12       1           2
# 999997                 12       1           1
# 999998                 12       1           1
# 999999                 12       2           2
#
#         User Total Time Watching Streams  Total Time Watching Streamer  \
# 0                                    124                            23
# 1                                    124                             4
# 2                                    124                            10
# 3                                    124                             9
# 4                                    124                            23
# ...                                  ...                           ...
# 999995                                16                             2
# 999996                                16                             2
# 999997                                16                             1
# 999998                                16                             1
# 999999                                16                             3
#
#         Percentage of Time Watching Streamer
# 0                                  18.548387
# 1                                   3.225806
# 2                                   8.064516
# 3                                   7.258065
# 4                                  18.548387
# ...                                      ...
# 999995                             12.500000
# 999996                             12.500000
# 999997                              6.250000
# 999998                              6.250000
# 999999                             18.750000
#
# [1000000 rows x 11 columns]

# %%
#Still deciding if removing USER ID and STREAM ID would be correct

# %% [markdown]
# ## Recommendation System - Collaborative Filtering

# %% [raw]
# Issues:
# - Our data is huge. K means wont work due to the curse of dimensionality. I am brainstorming/looking for other options currently.
# - Options include extrapolating results from a subsection of the data, but I would like to use all data if possible.
# - Another option is to do some features reduction, but I believe there would be other ways to do this.
# - Looks like I need to do both in order to do this on a single machine. Other techniques would require multi-machine clustering techniques.
#
# Clustering Techniques
# - Clique subspace clustering  (I am unsure if this can do prediction)
# - Probably want user based recommendation system
#
# Final Conclusion: Trying to attempt a Recommendation System with Collaborative Filtering using User-based nearest neighbor

# %%
df['Streamer ID'] = df['Streamer Username'].astype('category')
df['Streamer ID'] = df["Streamer ID"].cat.codes
df
# Out:
#         User ID    Stream ID Streamer Username  Time Start  Time Stop  \
# 0             1  33827518864             lirik          25         26
# 1             1  33870289680       giantwaffle         457        460
# 2             1  33876317008     blacklisted86         471        472
# 3             1  33882713200       cohhcarnage         544        550
# 4             1  33885628720             lirik         586        588
# ...         ...          ...               ...         ...        ...
# 999995    34374  33885521536       piazztwitch         571        573
# 999996    34374  33885545376          efesto96         571        573
# 999997    34374  33887753632              tfue         575        576
# 999998    34374  33888568352     therealmarzaa         578        579
# 999999    34374  33888952608           pow3rtv         579        581
#
#         Streamers Watched  Visits  Watch Time  \
# 0                      44       9           1
# 1                      44       2           3
# 2                      44       5           1
# 3                      44       3           6
# 4                      44       9           2
# ...                   ...     ...         ...
# 999995                 12       1           2
# 999996                 12       1           2
# 999997                 12       1           1
# 999998                 12       1           1
# 999999                 12       2           2
#
#         User Total Time Watching Streams  Total Time Watching Streamer  \
# 0                                    124                            23
# 1                                    124                             4
# 2                                    124                            10
# 3                                    124                             9
# 4                                    124                            23
# ...                                  ...                           ...
# 999995                                16                             2
# 999996                                16                             2
# 999997                                16                             1
# 999998                                16                             1
# 999999                                16                             3
#
#         Percentage of Time Watching Streamer  Streamer ID
# 0                                  18.548387        39015
# 1                                   3.225806        24208
# 2                                   8.064516         7517
# 3                                   7.258065        12158
# 4                                  18.548387        39015
# ...                                      ...          ...
# 999995                             12.500000        52463
# 999996                             12.500000        18239
# 999997                              6.250000        67028
# 999998                              6.250000        68244
# 999999                             18.750000        53492
#
# [1000000 rows x 12 columns]

# %%
#Making User-Item Sparse Matrix
def sparse_matrix(df):
    sparse_data = sparse.csr_matrix((df['Total Time Watching Streamer'].values,(df['User ID'].values, df['Streamer ID'].values)))
    return sparse_data

df1 = sparse_matrix(df)
df1
# Out:
# <34375x78197 sparse matrix of type '<class 'numpy.int64'>'
# 	with 491217 stored elements in Compressed Sparse Row format>

# %%
type(df1)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
def similarity(sparse_matrix, streamers, streamer_id):
    similarity = cosine_similarity(sparse_matrix.T, dense_output = False)
    no_of_similar_streamers = streamers.loc[streamer_id][0], similarity[streamer_id].count_nonzero()
    return no_of_similar_streamers

# %%
streamers = df[['Streamer Username', 'Streamer ID']]
streamers = streamers.drop_duplicates(subset = "Streamer Username")
streamers = streamers.set_index('Streamer ID').sort_index()
streamers
# Out:
#             Streamer Username
# Streamer ID
# 0                  001anthony
# 1                   001pickle
# 2              007kingchannel
# 3                     007zeus
# 4                      00hoon
# ...                       ...
# 78192          zzztantrikazzz
# 78193           zzzz1123x2018
# 78194                 zzzzydh
# 78195                 zzzzz87
# 78196              zzzzzzzach
#
# [78197 rows x 1 columns]

# %%
similarity(df1, streamers, 501)
# Out:
# ('404_otukare', 30)
